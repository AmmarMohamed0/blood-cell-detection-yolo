# %%
pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo26n.pt")

model.train(
    data="/content/data.yaml",
    epochs=10,
    imgsz=640,
    batch=8,
    device="cuda"
)
